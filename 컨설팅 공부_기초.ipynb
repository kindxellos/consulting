# %% [markdown]
# # 목표
#
# 1. 컨설팅 산업을 제대로 이해: 산업 = f(time)
# 2. 컨설팅에 사용되는 다양한 도구, 기법, 방법론 이해 및 활용
# 3. 나만의 framework 확립

# %% [markdown]
# # 정의
#
# - 컨설팅: 조언을 주는 것 > 솔루션을 제시하는 것
#
# - 솔루션: f(지식, 경험, 돈)
#
# (1) 어떤 정보를 바탕으로
# (2) 어떤 솔루션을
# (3) 어떻게 전달하느냐
#
# 논리/분석, 보고서작성(documentation), 발표(presentation)

# %% [markdown]
# # 경영컨설팅에 대한 다양한 정의들
#
# 기업으로 하여금 당면한 문제들을 분석, 해결할 수 있도록 또는 기업의 성공 사례를 타 기업에 접목시킬 수 있도록 도와주는 전문적인 서비스를 제공하는 것이다." Management Consulting: A Guide to the Profession
#
# 특별히 훈련 받고 경험을 쌓은 사람들이 기업 경영 상의 여러 가지 문제점들을 규명하고 해결할 수 있도록 실질적인 해결 방안을 제시하고 그러한 해결 방안들이 적기에 실시될 수 있도록 도와주기 위한 전문적인 서비스를 제공하는 것이다." Association of Consulting Management Engineers
#
# 특별한 분야의 전문성을 가진 전문가들이 자기들의 지식과 경험을 활용하여 경영 문제를 해결하고, 객관적이고 전반적인 시각에서 기업의 기획 과정을 지원하는 것을 말한다." Management Advisory Services Division
#
# 독립적이고 능력을 갖춘 사람(들)이 정책, 조직, 절차, 방법 상의 문제점들을 연구, 분석하고 적절한 해결책을 제시하며 나아가 이러한 해결책들을 수행할 수 있도록 돕는 것이다." Institute of Management Consults, United Kingdom
#
# 조직의 목적을 달성하는데 있어서 경영, 업무 상의 문제점을 해결하고 새로운 기회를 발견하고 포착하여, 학습을 촉진시키고 변화를 실현하는 조직 및 관리자를 지원하는 독립적인 전문, 자문 서비스" 국제노동기구(International Labour Organization)

# %% [markdown]
# # 컨설턴트에게 요구되는 역량
#
# (1) 독립된 입장 : 제3자 시각(視角) 이라는 독립된 입장
# (2) 특별한 훈련과 자질 : 특별한 훈련과 자질 습득을 위해 전문 분야의 지식 또는업무 경험을 축적해야 하며, 이의 입증을위해 박사나 MBA 학위를 요구
# (3) 자문의 제공 : 커뮤니케이션 스킬(Communication Skills)이 매우 중요
# (4) 문제의 규명과 분석 : 문제를 파악하고 분석하기 위해 전문적인 도구와 기법
# (5) 문제의 해결과 수행 : 창의적인 아이디어와 기간 내에 업무를 수행해야 할 수 있는 높은 업무 집중력이 요구

# %% [markdown]
# # 컨설턴트의 역할
#
# (1) 의사(Doctor)
#
# (2) 탐정(Detective): 가설 수립 및 검증
#
# (3) 세일맨(Salesperson) : 신규 사업 개발 추진
#
# (4) 용역 대행(Agent)

# %% [markdown]
# # 컨설턴트란
# 학문적 지식과 현장 경험을 통해
# 의뢰자의 문제를 분석해서
# 현재(As-Is)보다 나은 미래(To-Be)를 모델/모형으로 제시함으로써
# 기업의 경쟁력 강화에 도움을 주는 사람’
#
# 객관적 조언자, 선의의 중재자, 문제해결사, 코치/교육가

# %% [markdown]
# (1) 먼저 글로벌 기업에서 5년 이상 근무하라
#
# (2) 호수 위의 우아한, 그러나 부지런한 백조가 되라.
#
# (3) 초기의 성실함으로 고객의 신뢰를 얻어라.
#
# (4) 체력을 길러라.
#
# (5) 기업의 관리회계를 파악하라.

# %%
# !pip install IPython 
from IPython.display import Image

Image("컨설팅 분류.PNG")

# 운영/조직/전략/재무회계/규제준수위험/변화관리/진단
